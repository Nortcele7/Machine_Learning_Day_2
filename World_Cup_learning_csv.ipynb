# %%
print("Hello World")
# Out:
# Hello World

# %%
import pandas as pd

# %%
df = pd.read_csv("world_cup.csv")

# %%
print(df)
# Out:
#     Year                   Host  Teams      Champion       Runner-Up  \
# 0   2022                  Qatar     32     Argentina          France
# 1   2018                 Russia     32        France         Croatia
# 2   2014                 Brazil     32       Germany       Argentina
# 3   2010           South Africa     32         Spain     Netherlands
# 4   2006                Germany     32         Italy          France
# 5   2002  Korea Republic, Japan     32        Brazil         Germany
# 6   1998                 France     32        France          Brazil
# 7   1994          United States     24        Brazil           Italy
# 8   1990                  Italy     24  West Germany       Argentina
# 9   1986                 Mexico     24     Argentina    West Germany
# 10  1982                  Spain     24         Italy    West Germany
# 11  1978              Argentina     16     Argentina     Netherlands
# 12  1974                Germany     16  West Germany     Netherlands
# ...

# %%
df
# Out:
#     Year                   Host  Teams      Champion       Runner-Up  \
# 0   2022                  Qatar     32     Argentina          France
# 1   2018                 Russia     32        France         Croatia
# 2   2014                 Brazil     32       Germany       Argentina
# 3   2010           South Africa     32         Spain     Netherlands
# 4   2006                Germany     32         Italy          France
# 5   2002  Korea Republic, Japan     32        Brazil         Germany
# 6   1998                 France     32        France          Brazil
# 7   1994          United States     24        Brazil           Italy
# 8   1990                  Italy     24  West Germany       Argentina
# 9   1986                 Mexico     24     Argentina    West Germany
# 10  1982                  Spain     24         Italy    West Germany
# 11  1978              Argentina     16     Argentina     Netherlands
# 12  1974                Germany     16  West Germany     Netherlands
# ...

# %%
df = pd.read_csv("world_cup.csv",index_col=0)
df
# Out:
#                        Host  Teams      Champion       Runner-Up  \
# Year
# 2022                  Qatar     32     Argentina          France
# 2018                 Russia     32        France         Croatia
# 2014                 Brazil     32       Germany       Argentina
# 2010           South Africa     32         Spain     Netherlands
# 2006                Germany     32         Italy          France
# 2002  Korea Republic, Japan     32        Brazil         Germany
# 1998                 France     32        France          Brazil
# 1994          United States     24        Brazil           Italy
# 1990                  Italy     24  West Germany       Argentina
# 1986                 Mexico     24     Argentina    West Germany
# 1982                  Spain     24         Italy    West Germany
# 1978              Argentina     16     Argentina     Netherlands
# 1974                Germany     16  West Germany     Netherlands
# ...

# %%
df = pd.read_csv("world_cup.csv", header=0)

# %%
df
# Out:
#     Year                   Host  Teams      Champion       Runner-Up  \
# 0   2022                  Qatar     32     Argentina          France
# 1   2018                 Russia     32        France         Croatia
# 2   2014                 Brazil     32       Germany       Argentina
# 3   2010           South Africa     32         Spain     Netherlands
# 4   2006                Germany     32         Italy          France
# 5   2002  Korea Republic, Japan     32        Brazil         Germany
# 6   1998                 France     32        France          Brazil
# 7   1994          United States     24        Brazil           Italy
# 8   1990                  Italy     24  West Germany       Argentina
# 9   1986                 Mexico     24     Argentina    West Germany
# 10  1982                  Spain     24         Italy    West Germany
# 11  1978              Argentina     16     Argentina     Netherlands
# 12  1974                Germany     16  West Germany     Netherlands
# ...

# %%
df = pd.read_csv("world_cup.csv",usecols=["Host","Year","Champion","Runner-Up"])
df
# Out:
#     Year                   Host      Champion       Runner-Up
# 0   2022                  Qatar     Argentina          France
# 1   2018                 Russia        France         Croatia
# 2   2014                 Brazil       Germany       Argentina
# 3   2010           South Africa         Spain     Netherlands
# 4   2006                Germany         Italy          France
# 5   2002  Korea Republic, Japan        Brazil         Germany
# 6   1998                 France        France          Brazil
# 7   1994          United States        Brazil           Italy
# 8   1990                  Italy  West Germany       Argentina
# 9   1986                 Mexico     Argentina    West Germany
# 10  1982                  Spain         Italy    West Germany
# 11  1978              Argentina     Argentina     Netherlands
# 12  1974                Germany  West Germany     Netherlands
# 13  1970                 Mexico        Brazil           Italy
# ...

# %%
df = pd.read_csv("matches_1930_2022.csv")

# %%
df
# Out:
#          home_team away_team  home_score  home_xg  home_penalty  away_score  \
# 0        Argentina    France           3      3.3           4.0           3
# 1          Croatia   Morocco           2      0.7           NaN           1
# 2           France   Morocco           2      2.0           NaN           0
# 3        Argentina   Croatia           3      2.3           NaN           0
# 4          Morocco  Portugal           1      1.4           NaN           0
# ..             ...       ...         ...      ...           ...         ...
# 959      Argentina    France           1      NaN           NaN           0
# 960     Yugoslavia    Brazil           2      NaN           NaN           1
# 961        Romania      Peru           3      NaN           NaN           1
# 962  United States   Belgium           3      NaN           NaN           0
# 963         France    Mexico           4      NaN           NaN           1
#
# ...

# %%
df = pd.read_csv("world_cup.csv", usecols=["Host"], squeeze=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 df = pd.read_csv("world_cup.csv", usecols=["Host"], squeeze=True)
#
# TypeError: read_csv() got an unexpected keyword argument 'squeeze'

# %%
df = pd.read_csv("world_cup.csv", usecols=["Host"])
df["Host"]
# Out:
# 0                     Qatar
# 1                    Russia
# 2                    Brazil
# 3              South Africa
# 4                   Germany
# 5     Korea Republic, Japan
# 6                    France
# 7             United States
# 8                     Italy
# 9                    Mexico
# 10                    Spain
# 11                Argentina
# 12                  Germany
# 13                   Mexico
# 14                  England
# 15                    Chile
# 16                   Sweden
# 17              Switzerland
# 18                   Brazil
# 19                   France
# 20                    Italy
# 21                  Uruguay
# Name: Host, dtype: object

# %%
df = pd.read_csv("world_cup.csv", skiprows = [x for x in range(1,5)])

# %%
df
# Out:
#     Year                   Host  Teams      Champion       Runner-Up  \
# 0   2006                Germany     32         Italy          France
# 1   2002  Korea Republic, Japan     32        Brazil         Germany
# 2   1998                 France     32        France          Brazil
# 3   1994          United States     24        Brazil           Italy
# 4   1990                  Italy     24  West Germany       Argentina
# 5   1986                 Mexico     24     Argentina    West Germany
# 6   1982                  Spain     24         Italy    West Germany
# 7   1978              Argentina     16     Argentina     Netherlands
# 8   1974                Germany     16  West Germany     Netherlands
# 9   1970                 Mexico     16        Brazil           Italy
# 10  1966                England     16       England    West Germany
# 11  1962                  Chile     16        Brazil  Czechoslovakia
# 12  1958                 Sweden     16        Brazil          Sweden
# ...

# %%
df = pd.read_csv("world_cup.csv", nrows=10)

# %%
df
# Out:
#    Year                   Host  Teams      Champion     Runner-Up  \
# 0  2022                  Qatar     32     Argentina        France
# 1  2018                 Russia     32        France       Croatia
# 2  2014                 Brazil     32       Germany     Argentina
# 3  2010           South Africa     32         Spain   Netherlands
# 4  2006                Germany     32         Italy        France
# 5  2002  Korea Republic, Japan     32        Brazil       Germany
# 6  1998                 France     32        France        Brazil
# 7  1994          United States     24        Brazil         Italy
# 8  1990                  Italy     24  West Germany     Argentina
# 9  1986                 Mexico     24     Argentina  West Germany
#
#                               TopScorrer  Attendance  AttendanceAvg  Matches
# 0                      Kylian Mbappé - 8     3404252          53191       64
# 1                         Harry Kane - 6     3031768          47371       64
# ...

# %%
df = pd.read_csv("world_cup.csv",dtype={"Matches":float})

# %%
df
# Out:
#     Year                   Host  Teams      Champion       Runner-Up  \
# 0   2022                  Qatar     32     Argentina          France
# 1   2018                 Russia     32        France         Croatia
# 2   2014                 Brazil     32       Germany       Argentina
# 3   2010           South Africa     32         Spain     Netherlands
# 4   2006                Germany     32         Italy          France
# 5   2002  Korea Republic, Japan     32        Brazil         Germany
# 6   1998                 France     32        France          Brazil
# 7   1994          United States     24        Brazil           Italy
# 8   1990                  Italy     24  West Germany       Argentina
# 9   1986                 Mexico     24     Argentina    West Germany
# 10  1982                  Spain     24         Italy    West Germany
# 11  1978              Argentina     16     Argentina     Netherlands
# 12  1974                Germany     16  West Germany     Netherlands
# ...

# %%
df = pd.read_csv("world_cup.csv")

# %%
df
# Out:
#     Year                   Host  Teams      Champion       Runner-Up  \
# 0   2022                  Qatar     32     Argentina          France
# 1   2018                 Russia     32        France         Croatia
# 2   2014                 Brazil     32       Germany       Argentina
# 3   2010           South Africa     32         Spain     Netherlands
# 4   2006                Germany     32         Italy          France
# 5   2002  Korea Republic, Japan     32        Brazil         Germany
# 6   1998                 France     32        France          Brazil
# 7   1994          United States     24        Brazil           Italy
# 8   1990                  Italy     24  West Germany       Argentina
# 9   1986                 Mexico     24     Argentina    West Germany
# 10  1982                  Spain     24         Italy    West Germany
# 11  1978              Argentina     16     Argentina     Netherlands
# 12  1974                Germany     16  West Germany     Netherlands
# ...
